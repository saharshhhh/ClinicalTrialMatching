# %% [markdown]
# <a href="https://colab.research.google.com/github/saharshhhh/ClinicalTrialMatching/blob/main/app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langchain-community langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 55.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 27.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.18 which is incompatible.

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 62.5 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0.post1

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.4 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 68.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 107.9 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 12.9 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.0
#     Uninstalling scipy-1.16.0:
#       Successfully uninstalled scipy-1.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
# !pip install -q langchain langchain_community langchain_google_genai redis sentence-transformers openai tiktoken langchain-huggingface
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━ 240.2/363.4 MB 58.6 MB/s eta 0:00:03^C

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models import Word2Vec

# %%
import os

file_path = "/content/drive/MyDrive/clinicalTrials.csv"
print("File exists:", os.path.exists(file_path))
print("File size:", os.path.getsize(file_path), "bytes")
# Out:
# File exists: True
# File size: 519853591 bytes

# %%
data=pd.read_csv("/content/drive/MyDrive/clinicalTrials.csv", engine='python', on_bad_lines='warn', sep=',')
# Out:
# /tmp/ipython-input-1238423527.py:1: ParserWarning: Skipping line 4435: field larger than field limit (131072)
#
#   data=pd.read_csv("/content/drive/MyDrive/clinicalTrials.csv", engine='python', on_bad_lines='warn', sep=',')
# /tmp/ipython-input-1238423527.py:1: ParserWarning: Skipping line 17476: field larger than field limit (131072)
#
#   data=pd.read_csv("/content/drive/MyDrive/clinicalTrials.csv", engine='python', on_bad_lines='warn', sep=',')
# /tmp/ipython-input-1238423527.py:1: ParserWarning: Skipping line 46354: field larger than field limit (131072)
#
#   data=pd.read_csv("/content/drive/MyDrive/clinicalTrials.csv", engine='python', on_bad_lines='warn', sep=',')
# /tmp/ipython-input-1238423527.py:1: ParserWarning: Skipping line 77223: field larger than field limit (131072)
#
#   data=pd.read_csv("/content/drive/MyDrive/clinicalTrials.csv", engine='python', on_bad_lines='warn', sep=',')
# /tmp/ipython-input-1238423527.py:1: ParserWarning: Skipping line 77948: field larger than field limit (131072)
#
#   data=pd.read_csv("/content/drive/MyDrive/clinicalTrials.csv", engine='python', on_bad_lines='warn', sep=',')
# /tmp/ipython-input-1238423527.py:1: ParserWarning: Skipping line 101285: field larger than field limit (131072)
#
#   data=pd.read_csv("/content/drive/MyDrive/clinicalTrials.csv", engine='python', on_bad_lines='warn', sep=',')
# /tmp/ipython-input-1238423527.py:1: ParserWarning: Skipping line 113836: field larger than field limit (131072)
#
#   data=pd.read_csv("/content/drive/MyDrive/clinicalTrials.csv", engine='python', on_bad_lines='warn', sep=',')

# %%
data
# Out:
#         Unnamed: 0.1  Unnamed: 0   NCT Number  \
# 0                  0           1  NCT03302091
# 1                  1           2  NCT01948791
# 2                  2           5  NCT04621591
# 3                  3           6  NCT03130491
# 4                  4           8  NCT01580891
# ...              ...         ...          ...
# 117968        117975      150114  NCT00706654
# 117969        117976      150117  NCT05098054
# 117970        117977      150119  NCT06352554
# 117971        117978      150120  NCT00710554
# 117972        117979      150121  NCT03353454
#
#                                               Study Title  \
# 0       A Study in People With Normal Kidney Function ...
# 1       16w Interventional Study on Titration and Dose...
# 2                Case Series With Saneso 360° Gastroscope
# 3       European Study Evaluating the EMBLOK Embolic P...
# 4       Evaluate the Clinical Equivalence of Two Nafti...
# ...                                                   ...
# 117968  Intramuscular Depot Formulation of Aripiprazol...
# 117969  A Study of Soticlestat in Adults With Liver Fa...
# 117970  Susceptibility Testing In Neisseria Gonorrhoea...
# 117971  A Study of Sativex® for Pain Relief of Periphe...
# 117972  A Placebo-controlled Study of Maralixibat (SHP...
#
#                                            Study URL   Acronym  \
# 0       https://clinicaltrials.gov/study/NCT03302091       NaN
# 1       https://clinicaltrials.gov/study/NCT01948791  INSTINCT
# 2       https://clinicaltrials.gov/study/NCT04621591       NaN
# 3       https://clinicaltrials.gov/study/NCT03130491       NaN
# 4       https://clinicaltrials.gov/study/NCT01580891       NaN
# ...                                              ...       ...
# 117968  https://clinicaltrials.gov/study/NCT00706654    ASPIRE
# 117969  https://clinicaltrials.gov/study/NCT05098054       NaN
# 117970  https://clinicaltrials.gov/study/NCT06352554     STING
# 117971  https://clinicaltrials.gov/study/NCT00710554       NaN
# 117972  https://clinicaltrials.gov/study/NCT03353454       NaN
#
#               Study Status                                      Brief Summary  \
# 0                COMPLETED  The primary objective of the current study is ...
# 1                COMPLETED  To investigate the efficacy of Exelon capsule ...
# 2                COMPLETED  To confirm the procedural performance of the S...
# 3                COMPLETED  The primary objective is to evaluate the perfo...
# 4                COMPLETED  The objective of this study is to evaluate the...
# ...                    ...                                                ...
# 117968           COMPLETED  The purpose of the this trial is to evaluate t...
# 117969           COMPLETED  The main aim is to check the effect of a singl...
# 117970  NOT_YET_RECRUITING  This study aims to validate a novel antibiotic...
# 117971           COMPLETED  The purpose of this study is to evaluate the e...
# 117972           WITHDRAWN  The purpose of this study is to determine if t...
#
#        Study Results                                         Conditions  ...  \
# 0                YES                        Renal Insufficiency|Healthy  ...
# 1                YES                                Alzheimer's Disease  ...
# 2                 NO                                      EGD Procedure  ...
# 3                 NO                               Aortic Valve Disease  ...
# 4                 NO                                        Tinea Pedis  ...
# ...              ...                                                ...  ...
# 117968           YES                                      Schizophrenia  ...
# 117969           YES              Hepatic Impairment|Healthy Volunteers  ...
# 117970            NO           Diagnosis|Gonorrhea|Resistance Bacterial  ...
# 117971           YES                         Pain|Peripheral Neuropathy  ...
# 117972            NO  Progressive Familial Intrahepatic Cholestasis ...  ...
#
#                                              Study Design  \
# 0       Allocation: NON_RANDOMIZED|Intervention Model:...
# 1       Allocation: NA|Intervention Model: SINGLE_GROU...
# 2       Allocation: NA|Intervention Model: SINGLE_GROU...
# 3       Allocation: NA|Intervention Model: SINGLE_GROU...
# 4       Allocation: RANDOMIZED|Intervention Model: PAR...
# ...                                                   ...
# 117968  Allocation: RANDOMIZED|Intervention Model: PAR...
# 117969  Allocation: NON_RANDOMIZED|Intervention Model:...
# 117970          Observational Model: |Time Perspective: p
# 117971  Allocation: RANDOMIZED|Intervention Model: PAR...
# 117972  Allocation: RANDOMIZED|Intervention Model: PAR...
#
#                                                Other IDs  Start Date  \
# 0                               1386-0002|2017-002180-18  2017-10-17
# 1                                           CENA713BCN05     2014-08
# 2                                            SAN360UGICL  2020-08-01
# 3                                            CLP002-2016  2017-03-08
# 4                                            NTFC 1105.0     2012-05
# ...                                                  ...         ...
# 117968                                         31-07-247     2008-09
# 117969                       TAK-935-1010|2021-006373-29  2021-10-29
# 117970  2023/ETH02474:STING|224842/Z/21/Z|75A50122C00028  2024-04-08
# 117971                                          GWCL0405     2005-08
# 117972                         SHP625-306|2017-003138-99  2018-10-25
#
#        Primary Completion Date Completion Date First Posted  \
# 0                   2018-08-16      2018-08-16   2017-10-04
# 1                      2015-09         2015-09   2013-09-24
# 2                   2020-08-30      2020-09-09   2020-11-09
# 3                   2021-11-01      2022-01-28   2017-04-26
# 4                      2013-03         2013-07   2012-04-19
# ...                        ...             ...          ...
# 117968                 2012-08         2012-08   2008-06-27
# 117969              2022-05-31      2022-06-07   2021-10-28
# 117970              2024-12-30      2025-01-30   2024-04-08
# 117971                 2006-10         2006-10   2008-07-04
# 117972              2020-06-15      2020-06-15   2017-11-27
#
#        Results First Posted Last Update Posted  \
# 0                2021-06-04         2021-06-04
# 1                2017-02-13         2017-02-13
# 2                       NaN         2020-11-10
# 3                       NaN         2024-03-05
# 4                       NaN         2014-05-06
# ...                     ...                ...
# 117968           2013-08-14         2013-08-14
# 117969           2024-02-02         2024-02-02
# 117970                  NaN         2024-04-09
# 117971           2012-09-14         2023-05-03
# 117972                  NaN         2019-03-18
#
#                                                 Locations  \
# 0       CRS Clinical Research Services Kiel GmbH, Kiel...
# 1       Novartis Investigative Site, Beijing, 100053, ...
# 2       Valley Endoscopy Center, Saint Clairsville, Oh...
# 3       Hospital San Donato, Milan, Milano, 20097, Ita...
# 4                                                     NaN
# ...                                                   ...
# 117968  Cerritos, California, 90703, United States|Esc...
# 117969  Velocity, Edgewater, Florida, 32132, United St...
# 117970                                                NaN
# 117971  Pain Clinic Office, Gartnavel General Hospital...
# 117972                                                NaN
#
#                                           Study Documents
# 0       Study Protocol, https://cdn.clinicaltrials.gov...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 117968                                                NaN
# 117969  Study Protocol, https://cdn.clinicaltrials.gov...
# 117970                                                NaN
# 117971                                                NaN
# 117972                                                NaN
#
# [117973 rows x 32 columns]

# %%
data.shape
# Out:
# (117973, 32)

# %%
df=pd.DataFrame(data)

# %%
df.shape
# Out:
# (117973, 32)

# %%
import sys
import csv
from langchain_community.document_loaders import CSVLoader

# Increase the field size limit
csv.field_size_limit(sys.maxsize)

loader = CSVLoader(file_path="/content/drive/MyDrive/clinicalTrials.csv", encoding="utf-8")
docs = loader.load()
print(len(docs), "documents loaded")
# Out:
# 117980 documents loaded

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/clinicalTrials.csv")
df["content"] = df.apply(lambda x: f"Title: {x['Study Title']} | Condition: {x['Conditions']}", axis=1)
texts = df["content"].tolist()

print(df.columns)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'NCT Number', 'Study Title', 'Study URL',
#        'Acronym', 'Study Status', 'Brief Summary', 'Study Results',
#        'Conditions', 'Interventions', 'Primary Outcome Measures',
#        'Secondary Outcome Measures', 'Other Outcome Measures', 'Sponsor',
#        'Collaborators', 'Sex', 'Age', 'Phases', 'Enrollment', 'Funder Type',
#        'Study Type', 'Study Design', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'content'],
#       dtype='object')

# %% [markdown]
# # Task
# Set up a retrieval-based question answering system using LangChain, Google Generative AI, and a FAISS vector store.

# %% [markdown]
# ## Set up google ai api key
#
# ### Subtask:
# Ensure the Google AI API key is set up securely in the environment.

# %% [markdown]
# **Reasoning**:
# Set the Google API key as an environment variable.

# %% [markdown]
# **Reasoning**:
# Import the necessary libraries and set the environment variable for the Google API key.

# %%
import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %% [markdown]
# ## Set up vector store
#
# ### Subtask:
# Create a FAISS vector store from the generated embeddings and the documents.

# %%
df["content"] = df.apply(lambda x: f"Title: {x['Study Title']} | Condition: {x['Conditions']}", axis=1)
texts = df["content"].tolist()

from sentence_transformers import SentenceTransformer
from langchain.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings # Import HuggingFaceEmbeddings

embedding_model = SentenceTransformer("pritamdeka/BioBERT-mnli-snli-scinli-scitail-mednli-stsb")
# Wrap the SentenceTransformer model in HuggingFaceEmbeddings
embeddings_instance = HuggingFaceEmbeddings(model_name="pritamdeka/BioBERT-mnli-snli-scinli-scitail-mednli-stsb",
                                            model_kwargs={'device': 'cuda'}) # Specify device if needed

embeddings = embedding_model.encode(texts, convert_to_tensor=True)

# Create a list of (text, embedding) pairs
text_embedding_pairs = list(zip(texts, embeddings.cpu().numpy()))

# Pass the HuggingFaceEmbeddings instance as embedding_function
vectorstore = FAISS.from_embeddings(text_embedding_pairs, embeddings_instance)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/691 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/412 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# /tmp/ipython-input-487964301.py:10: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings_instance = HuggingFaceEmbeddings(model_name="pritamdeka/BioBERT-mnli-snli-scinli-scitail-mednli-stsb",
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %% [markdown]
# **Reasoning**:
# The error indicates that the dataframe `df` is not defined. I need to reload the dataframe and create the 'content' column again before proceeding with generating embeddings and creating the FAISS index.

# %%
retriever = vectorstore.as_retriever()

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# Initialize the Google Generative AI model
llm = ChatGoogleGenerativeAI(model="gemini-pro")

# %%
from langchain.chains import RetrievalQA

# Build the Retrieval QA chain
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever
)

# %%
# Run the Retrieval QA chain with a sample query
query = "What are some clinical trials for cancer?"
# Use invoke instead of run
response = qa_chain.invoke({'query': query})
print(response)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 8.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 16.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 32.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2283247656.py in <cell line: 0>()
#       2 query = "What are some clinical trials for cancer?"
#       3 # Use invoke instead of run
# ----> 4 response = qa_chain.invoke({'query': query})
#       5 print(response)
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     163             self._validate_inputs(inputs)
#     164             outputs = (
# --> 165                 self._call(inputs, run_manager=run_manager)
#     166                 if new_arg_supported
#     167                 else self._call(inputs)
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/retrieval_qa/base.py in _call(self, inputs, run_manager)
#     157         else:
#     158             docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 159         answer = self.combine_documents_chain.run(
#     160             input_documents=docs,
#     161             question=question,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     187                 warned = True
#     188                 emit_warning()
# --> 189             return wrapped(*args, **kwargs)
#     190
#     191         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     630
#     631         if kwargs and not args:
# --> 632             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     633                 _output_key
#     634             ]
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     187                 warned = True
#     188                 emit_warning()
# --> 189             return wrapped(*args, **kwargs)
#     190
#     191         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     408         }
#     409
# --> 410         return self.invoke(
#     411             inputs,
#     412             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     163             self._validate_inputs(inputs)
#     164             outputs = (
# --> 165                 self._call(inputs, run_manager=run_manager)
#     166                 if new_arg_supported
#     167                 else self._call(inputs)
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/combine_documents/base.py in _call(self, inputs, run_manager)
#     141         # Other keys are assumed to be needed for LLM prediction
#     142         other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 143         output, extra_return_dict = self.combine_docs(
#     144             docs,
#     145             callbacks=_run_manager.get_child(),
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/combine_documents/stuff.py in combine_docs(self, docs, callbacks, **kwargs)
#     261         inputs = self._get_inputs(docs, **kwargs)
#     262         # Call predict on the LLM.
# --> 263         return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#     264
#     265     async def acombine_docs(
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/llm.py in predict(self, callbacks, **kwargs)
#     323                 completion = llm.predict(adjective="funny")
#     324         """
# --> 325         return self(kwargs, callbacks=callbacks)[self.output_key]
#     326
#     327     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     187                 warned = True
#     188                 emit_warning()
# --> 189             return wrapped(*args, **kwargs)
#     190
#     191         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     408         }
#     409
# --> 410         return self.invoke(
#     411             inputs,
#     412             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     163             self._validate_inputs(inputs)
#     164             outputs = (
# --> 165                 self._call(inputs, run_manager=run_manager)
#     166                 if new_arg_supported
#     167                 else self._call(inputs)
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     125         run_manager: Optional[CallbackManagerForChainRun] = None,
#     126     ) -> dict[str, str]:
# --> 127         response = self.generate([inputs], run_manager=run_manager)
#     128         return self.create_outputs(response)[0]
#     129
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     137         callbacks = run_manager.get_child() if run_manager else None
#     138         if isinstance(self.llm, BaseLanguageModel):
# --> 139             return self.llm.generate_prompt(
#     140                 prompts,
#     141                 stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     978     ) -> LLMResult:
#     979         prompt_messages = [p.to_messages() for p in prompts]
# --> 980         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     981
#     982     @override
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     797             try:
#     798                 results.append(
# --> 799                     self._generate_with_cache(
#     800                         m,
#     801                         stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1043             result = generate_from_stream(iter(chunks))
#    1044         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1045             result = self._generate(
#    1046                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1047             )
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    1593             **kwargs,
#    1594         )
# -> 1595         response: GenerateContentResponse = _chat_with_retry(
#    1596             request=request,
#    1597             **kwargs,
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _chat_with_retry(generation_method, **kwargs)
#     245         else kwargs
#     246     )
# --> 247     return _chat_with_retry(**params)
#     248
#     249
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     334             copy = self.copy()
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#     338         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     483             elif isinstance(do, DoSleep):
#     484                 retry_state.prepare_for_next_attempt()
# --> 485                 self.sleep(do)
#     486             else:
#     487                 return do  # type: ignore[no-any-return]
#
# /usr/local/lib/python3.11/dist-packages/tenacity/nap.py in sleep(seconds)
#      29     This is the default strategy, and may be mocked out for unit testing.
#      30     """
# ---> 31     time.sleep(seconds)
#      32
#      33
#
# KeyboardInterrupt:
